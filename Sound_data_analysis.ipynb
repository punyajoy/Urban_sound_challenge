# %%
import IPython.display as ipd
import librosa
import librosa.display

data, sampling_rate = librosa.load('../urban_sound_data/train/Train/5.wav')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-33-86f337ee8868> in <module>()
#       3 import librosa.display
#       4
# ----> 5 data, sampling_rate = librosa.load('../urban_sound_data/train/Train/5.wav')
#
# /home/punyajoy/anaconda3/lib/python3.6/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     110
#     111     y = []
# --> 112     with audioread.audio_open(os.path.realpath(path)) as input_file:
#     113         sr_native = input_file.samplerate
#     114         n_channels = input_file.channels
#
# /home/punyajoy/anaconda3/lib/python3.6/site-packages/audioread/__init__.py in audio_open(path)
#      78     from . import rawread
#      79     try:
# ---> 80         return rawread.RawAudioFile(path)
#      81     except DecodeError:
#      82         pass
#
# /home/punyajoy/anaconda3/lib/python3.6/site-packages/audioread/rawread.py in __init__(self, filename)
#      59     """
#      60     def __init__(self, filename):
# ---> 61         self._fh = open(filename, 'rb')
#      62
#      63         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/5.wav'

# %%
% pylab inline
import os
import pandas as pd
import librosa
import glob 

plt.figure(figsize=(12, 4))
librosa.display.waveplot(data, sr=sampling_rate)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
train = pd.read_csv('../urban_sound_data/train/train.csv')


i = random.choice(train.index)

data_dir='../urban_sound_data/train/'
print('Class: ', train.Class[i])
x, sr = librosa.load('../urban_sound_data/train/Train/' + str(train.ID[i]) + '.wav')

plt.figure(figsize=(12, 4))
librosa.display.waveplot(x, sr=sr)
# Out:
# Class:  dog_bark

# %%
train.Class.value_counts()
# Out:
# jackhammer          668
# engine_idling       624
# siren               607
# air_conditioner     600
# children_playing    600
# dog_bark            600
# drilling            600
# street_music        600
# car_horn            306
# gun_shot            230
# Name: Class, dtype: int64

# %%
def parser(row):
        # function to load files and extract features
        file_name = os.path.join(os.path.abspath(data_dir), 'Train/', str(row.ID) + '.wav')
        print(file_name)
        # handle exception to check if there isn't a file which is corrupted
        try:
        # here kaiser_fast is a technique used for faster extraction
            data, sampling_rate = librosa.load(file_name)
        except:
            print("Error encountered while parsing file: ", file_name)
            return None, None
        X, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
        # we extract mfcc feature from data
        mfccs = np.mean(librosa.feature.mfcc(y=X, sr=sample_rate, n_mfcc=40).T,axis=0) 

        feature = mfccs
        label = row.Class
 
        return [feature, label]

# %%
temp = train.apply(parser, axis=1)
temp.columns = ['feature', 'label']
# Out:
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/0.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/0.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/1.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/2.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/3.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/4.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/6.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/6.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/10.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/11.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/12.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/15.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/17.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/17.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/18.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/18.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/19.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/19.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/20.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/22.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/24.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/26.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/27.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/32.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/32.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/33.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/33.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/35.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/35.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/36.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/37.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/38.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/40.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/42.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/42.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/43.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/44.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/45.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/46.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/47.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/48.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/49.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/49.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/50.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/52.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/54.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/56.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/57.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/59.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/60.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/61.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/61.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/63.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/65.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/66.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/66.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/67.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/68.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/71.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/72.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/72.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/74.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/76.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/77.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/78.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/79.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/79.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/80.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/80.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/81.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/82.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/82.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/83.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/84.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/87.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/87.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/88.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/90.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/91.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/91.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/92.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/93.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/97.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/99.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/99.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/100.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/101.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/101.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/103.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/104.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/105.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/105.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/113.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/113.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/114.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/114.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/116.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/117.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/117.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/118.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/119.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/120.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/121.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/123.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/125.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/128.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/130.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/131.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/132.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/134.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/134.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/135.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/135.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train
wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8613.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8614.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8614.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8615.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8616.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8616.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8617.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8617.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8618.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8620.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8621.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8624.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8625.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8626.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8627.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8628.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8630.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8632.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8635.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8636.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8637.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8637.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8639.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8640.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8641.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8643.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8644.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8646.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8649.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8650.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8651.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8651.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8653.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8654.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8654.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8656.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8657.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8658.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8659.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8660.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8660.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8663.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8663.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8664.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8664.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8665.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8666.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8667.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8670.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8673.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8673.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8675.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8676.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8677.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8678.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8679.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8679.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8681.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8682.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8684.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8685.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8690.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8691.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8693.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8694.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8695.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8695.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8699.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8701.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8701.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8703.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8703.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8704.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8704.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8705.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8705.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8706.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8706.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8707.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8709.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8709.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8710.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8711.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8712.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8712.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8713.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8714.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8714.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8715.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8716.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8717.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8717.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8720.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8721.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8721.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8722.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8723.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8724.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8724.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8725.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8725.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8726.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8727.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8728.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8728.wav
# /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8729.wav
# Error encountered while parsing file:  /media/punyajoy/New Volume1/computerscience/my_projects/urban_sound_data/train/Train/8729.wav

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils import np_utils
temp=temp.dropna()

X = np.array(temp.feature.tolist())
y = np.array(temp.label.tolist())

lb = LabelEncoder()

y = np_utils.to_categorical(lb.fit_transform(y))

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Convolution2D, MaxPooling2D
from keras.optimizers import Adam
from keras.utils import np_utils
from sklearn import metrics 

num_labels = y.shape[1]
filter_size = 2

# build model
model = Sequential()
model.add(Dense(256, input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(256))
model.add(Activation('relu'))
model.add(Dropout(0.5))

model.add(Dense(num_labels))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-74-c87c224bacd4> in <module>()
#      21
#      22 model.add(Dense(num_labels))
# ---> 23 model.add(Activation('softmax'))
#      24
#      25 model.compile(loss='categorical_crossentropy', metrics=['accuracy'], optimizer='adam')
#
# /home/punyajoy/anaconda3/lib/python3.6/site-packages/keras/engine/sequential.py in add(self, layer)
#     185                 self.inputs = network.get_source_inputs(self.outputs[0])
#     186         elif self.outputs:
# --> 187             output_tensor = layer(self.outputs[0])
#     188             if isinstance(output_tensor, list):
#     189                 raise TypeError('All layers in a Sequential model '
#
# /home/punyajoy/anaconda3/lib/python3.6/site-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     458             # Actually call the layer,
#     459             # collecting output(s), mask(s), and shape(s).
# --> 460             output = self.call(inputs, **kwargs)
#     461             output_mask = self.compute_mask(inputs, previous_mask)
#     462
#
# /home/punyajoy/anaconda3/lib/python3.6/site-packages/keras/layers/core.py in call(self, inputs)
#     303
#     304     def call(self, inputs):
# --> 305         return self.activation(inputs)
#     306
#     307     def get_config(self):
#
# /home/punyajoy/anaconda3/lib/python3.6/site-packages/keras/activations.py in softmax(x, axis)
#      27     ndim = K.ndim(x)
#      28     if ndim == 2:
# ---> 29         return K.softmax(x)
#      30     elif ndim > 2:
#      31         e = K.exp(x - K.max(x, axis=axis, keepdims=True))
#
# /home/punyajoy/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in softmax(x, axis)
#    3147         A tensor.
#    3148     """
# -> 3149     return tf.nn.softmax(x, axis=axis)
#    3150
#    3151
#
# TypeError: softmax() got an unexpected keyword argument 'axis'

# %%
model.fit(X, y, batch_size=32, epochs=5, validation_data=(val_x, val_y))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-75-e101359b9554> in <module>()
# ----> 1 model.fit(X, y, batch_size=32, epochs=5, validation_data=(val_x, val_y))
#
# NameError: name 'val_x' is not defined
